# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanslusokurut/Sales-Prediction/blob/main/Project_2_Part_3_Stanslus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/Data Science/Datasets/Machine Learning Data/Food Security Nationals.xlsx'
#File has headers
df = pd.read_excel(filename)
df.head()
# Out:
#       a_date a_state a_county      a_payam                      a_context  \
# 0 2022-06-09   Unity  Rubkona  Bentiu Town  Community village (host/IDPs)
# 1 2022-06-09   Unity  Rubkona  Bentiu Town  Community village (host/IDPs)
# 2 2022-06-09   Unity  Rubkona  Bentiu Town  Community village (host/IDPs)
# 3 2022-06-09   Unity  Rubkona  Bentiu Town  Community village (host/IDPs)
# 4 2022-06-10   Lakes  Awerial        Puluk  Community village (host/IDPs)
#
#   a_poptype        a_camp a_camp_oth      a_activity a_interview_mode  ...  \
# 0       NaN   Bentiu town        NaN  GFD activities              NaN  ...
# 1       NaN   Bentiu town        NaN  GFD activities              NaN  ...
# 2       NaN  Rubkona town        NaN  GFD activities              NaN  ...
# 3       NaN   Bentiu town        NaN  GFD activities              NaN  ...
# 4       NaN     Mingkaman        NaN  GFD activities              NaN  ...
#
#   total_fexcari  fexcari expgroup stress  crisis emergency caricop  \
# 0       68300.0     60.0        2      0       0         1     3.0
# 1       26900.0     89.0        4      0       0         1     4.0
# 2       53500.0     79.0        4      0       0         1     4.0
# 3       31600.0     69.0        3      0       0         1     3.5
# 4       84000.0     43.0        1      0       0         0     1.0
#
#   fcsgtoCarig    fs _index
# 0           1  2.00      1
# 1           4  4.00      2
# 2           1  2.50      3
# 3           3  3.25      4
# 4           4  2.50      5
#
# [5 rows x 1454 columns]

# %%
#Set pandas to show all rows of results
pd.set_option('display.max_rows', None)

# %%
df.shape
# Out:
# (3186, 1454)

# %%
#Drop columns which have majority as null
df = df.loc[:, df.isnull().sum()/len(df)<0.50]

# %%
df.shape
# Out:
# (3186, 1062)

# %%
df.dtypes
# Out:
# a_date                                                                                                                                      datetime64[ns]
# a_state                                                                                                                                             object
# a_county                                                                                                                                            object
# a_payam                                                                                                                                             object
# a_context                                                                                                                                           object
# a_camp                                                                                                                                              object
# a_activity                                                                                                                                          object
# noben                                                                                                                                                int64
# respdnt_sex                                                                                                                                         object
# respdnt_ishead                                                                                                                                      object
# respdnt_age                                                                                                                                          int64
# assist_received                                                                                                                                     object
# assist_modality                                                                                                                                     object
# assist_days                                                                                                                                        float64
# assist_rationsize                                                                                                                                   object
# gfd                                                                                                                                                  int64
# ffa                                                                                                                                                  int64
# food                                                                                                                                                 int64
# cash                                                                                                                                                 int64
# voucher                                                                                                                                              int64
# milling                                                                                                                                              int64
# valid                                                                                                                                                int64
# rrm                                                                                                                                                  int64
# head_marital                                                                                                                                        object
# head_provider                                                                                                                                       object
# hh_size                                                                                                                                            float64
# c_s_ag1m                                                                                                                                           float64
# c_s_ag1f                                                                                                                                           float64
# c_s_ag2m                                                                                                                                           float64
# c_s_ag2f                                                                                                                                           float64
# c_s_ag3f                                                                                                                                           float64
# c_s_ag3m                                                                                                                                           float64
# c_s_ag4f                                                                                                                                           float64
# c_s_ag4m                                                                                                                                           float64
# c_s_ag5f                                                                                                                                           float64
# c_s_ag5m                                                                                                                                           float64
# n_w659                                                                                                                                             float64
# n_plw_t                                                                                                                                            float64
# n_plw                                                                                                                                              float64
# n_u5                                                                                                                                               float64
# n_u2                                                                                                                                               float64
# n_males                                                                                                                                            float64
# n_females                                                                                                                                          float64
# n_u18                                                                                                                                              float64
# n_decision_m                                                                                                                                       float64
# n_decision_f                                                                                                                                       float64
# totalhh                                                                                                                                            float64
# c_card                                                                                                                                              object
# c_hh_ill                                                                                                                                            object
# c_hh_disable                                                                                                                                       float64
# DISABILITY_count                                                                                                                                   float64
# c_hh_minors                                                                                                                                         object
# c_hh_orphaned                                                                                                                                       object
# c_hh_plw                                                                                                                                           float64
# school_1                                                                                                                                            object
# school_2                                                                                                                                            object
# school_3/My child was recruited into armed services/groups                                                                                           int64
# school_3/My child was sent for marriage                                                                                                              int64
# school_3/Ongoing insecurity                                                                                                                          int64
# school_3/Schools were destroyed due to conflict                                                                                                      int64
# school_3/Schools are too far                                                                                                                         int64
# school_3/Need them to work (at home or outside)                                                                                                      int64
# school_3/Need to bring income                                                                                                                        int64
# school_3/No food at school                                                                                                                           int64
# school_3/Lack of school Fees                                                                                                                         int64
# school_3/Other. Specify in the next screen.                                                                                                          int64
# school_5/My child was recruited into armed services/groups                                                                                           int64
# school_5/My child was sent for marriage                                                                                                              int64
# school_5/Ongoing insecurity                                                                                                                          int64
# school_5/Schools were destroyed due to conflict                                                                                                      int64
# school_5/Schools are too far                                                                                                                         int64
# school_5/Need them to work (at home or outside)                                                                                                      int64
# school_5/Need to bring income                                                                                                                        int64
# school_5/No food at school                                                                                                                           int64
# school_5/Lack of school Fees                                                                                                                         int64
# school_5/Other. Specify in the next screen.                                                                                                          int64
# school_7                                                                                                                                            object
# school_10/Food assistance                                                                                                                            int64
# school_10/Education                                                                                                                                  int64
# school_10/Safety                                                                                                                                     int64
# school_10/Other                                                                                                                                      int64
# d_bsfpu5                                                                                                                                            object
# d_tsfpu5                                                                                                                                            object
# option_1                                                                                                                                            object
# option_1/TSFP                                                                                                                                        int64
# option_1/School Feeding                                                                                                                              int64
# option_1/FFA                                                                                                                                         int64
# option_1/Urban project                                                                                                                               int64
# option_1/None                                                                                                                                        int64
# option_2/TSFP                                                                                                                                        int64
# option_2/School Feeding                                                                                                                              int64
# option_2/GFD                                                                                                                                         int64
# option_2/Urban project                                                                                                                               int64
# option_2/None                                                                                                                                        int64
# nut_messages                                                                                                                                        object
# which_messages/Breastfeeding practices                                                                                                               int64
# which_messages/Complementary feeding (this includes starting feeding babies at 6 months, how to prepare, how much to give and how often)             int64
# which_messages/Maternal health ( antenatal clinic visits, diet changes including those rich in iron etc)                                             int64
# which_messages/Diet diversity (general for the family i.e eating 6 food groups)                                                                      int64
# which_messages/Hygiene and sanitation ( Washing (mother and baby) hands before and after feeding, washing hands after changing the baby)             int64
# which_messages/Other (specify)                                                                                                                       int64
# e_pillar/Pillar 1: Capacity of arable land                                                                                                           int64
# e_pillar/Pillar 2: Community infrastructure                                                                                                          int64
# e_pillar/Pillar 3: Natural resource management and climate adaptation                                                                                int64
# e_pillar/Pillar 4. Skills development                                                                                                                int64
# e_activity_p1/PI: Land clearing and plantation                                                                                                       int64
# e_activity_p1/PI: Vegetable gardening                                                                                                                int64
# e_activity_p1/PI: Compost preparation                                                                                                                int64
# e_activity_p1/PI: Construction of solar driers                                                                                                       int64
# e_activity_p1/PI: Construction of grain stores                                                                                                       int64
# e_activity_p1/PI: Beekeeping                                                                                                                         int64
# e_activity_p1/PI: Other                                                                                                                              int64
# e_activity_p2/PII: Community access road construction                                                                                                int64
# e_activity_p2/PII: Nutrition centre                                                                                                                  int64
# e_activity_p2/PII: Dyke construction (roads)                                                                                                         int64
# e_activity_p2/PII: Multi-purpose water pond construction                                                                                             int64
# e_activity_p2/PII: Fish pond construction                                                                                                            int64
# e_activity_p2/PII: Shallow wells construction                                                                                                        int64
# e_activity_p2/PII: School class room construction                                                                                                    int64
# e_activity_p2/PII: Youth centre                                                                                                                      int64
# e_activity_p2/PII: Clinic                                                                                                                            int64
# e_activity_p2/PII: Grain store                                                                                                                       int64
# e_activity_p2/PII: Other                                                                                                                             int64
# e_activity_p3/PIII: Tree nursery - seedling production/plantation                                                                                    int64
# e_activity_p3/PIII: Seedling pit excavation                                                                                                          int64
# e_activity_p3/PIII: Dyke construction (flood-control)                                                                                                int64
# e_activity_p3/PIII: Vetiver multiplication                                                                                                           int64
# e_activity_p3/PIII: Other                                                                                                                            int64
# e_activity_p4/PIV: Training in Livelihood developmen                                                                                                 int64
# e_activity_p4/PIV: Training in Infrastructure development                                                                                            int64
# e_activity_p4/PIV: Training in Environmental rehabilitation                                                                                          int64
# e_activity_p4/PIV: Training in Cross-cutting issues                                                                                                  int64
# e_activity_p4/Other                                                                                                                                  int64
# e_training/Establishment of nurseries and seedling production                                                                                        int64
# e_training/Seedling planting including fruit trees                                                                                                   int64
# e_training/Development of flood control dykes                                                                                                        int64
# e_training/Improved technologies on livelihood activities                                                                                            int64
# e_training/Environmental issues                                                                                                                      int64
# e_training/Project management                                                                                                                        int64
# e_training/Other                                                                                                                                     int64
# d_criteria                                                                                                                                          object
# d_criteria_selection/Families with children under 5 years on malnutrition treatment                                                                  int64
# d_criteria_selection/Families with pregnant and/or lactating Women on malnutrition treatment                                                         int64
# d_criteria_selection/Families headed by children                                                                                                     int64
# d_criteria_selection/Families with low income or headed by vulnerables                                                                               int64
# d_criteria_selection/Food insecure housheolds                                                                                                        int64
# d_criteria_selection/Families with high dependency ratio or with very few income earning members                                                     int64
# d_criteria_selection/Households with a high dependency ratio                                                                                         int64
# d_criteria_selection/Female-headed households (recently widowed/abandoned)                                                                           int64
# d_criteria_selection/Households a member discharged/cured from an OTP/TSFP                                                                           int64
# d_criteria_selection/Households with chronically ill/disabled members                                                                                int64
# d_criteria_selection/Split up households (food scarcity)                                                                                             int64
# d_criteria_selection/Households facing zero-sum coping                                                                                               int64
# d_criteria_selection/Households without access to productive assets                                                                                  int64
# d_criteria_selection/Daily wage-earners or households with no reliable income                                                                        int64
# d_criteria_selection/Other CBPP defined criteria                                                                                                     int64
# d_bens_selection/Community/traditional leader                                                                                                        int64
# d_bens_selection/Distribution staff                                                                                                                  int64
# d_bens_selection/Local Authorities                                                                                                                   int64
# d_bens_selection/Management committee                                                                                                                int64
# d_bens_selection/Partner                                                                                                                             int64
# d_bens_selection/WFP                                                                                                                                 int64
# d_bens_selection/I do not know                                                                                                                       int64
# d_bens_selection/Other                                                                                                                               int64
# d_asst_sel                                                                                                                                          object
# d_ben_mis                                                                                                                                           object
# assist_not_reason/Low assistance coverage (more people in need)                                                                                      int64
# assist_not_reason/The selection process was Corrupted, had to pay money                                                                              int64
# assist_not_reason/Because they did not meet the targeting requirements                                                                               int64
# assist_not_reason/Because they were absent during selection and registration                                                                         int64
# assist_not_reason/The area covered was too small to include all the vulnerable                                                                       int64
# assist_not_reason/Fewer registration cards provided                                                                                                  int64
# assist_not_reason/Because they are not farming households                                                                                            int64
# assist_not_reason/Because they were not related to those who did the selection                                                                       int64
# assist_not_reason/Household did not have members who could participate in the work                                                                   int64
# assist_not_reason/Priority was given the most vulnerable                                                                                             int64
# assist_not_reason/The selection criteria were not clear                                                                                              int64
# assist_not_reason/Don't know                                                                                                                         int64
# assist_not_reason/Other                                                                                                                              int64
# d_hh_pay                                                                                                                                            object
# d_fam_har                                                                                                                                           object
# grad_crite/Completed 3 years in the FFA programme                                                                                                    int64
# grad_crite/HH was food sufficient (able to withstand shocks without FFA assistance)                                                                  int64
# grad_crite/Created 2-3 feddans of crop farm on top of the farm around the homestead                                                                  int64
# grad_crite/Created 400 m2 of vegetable gardening that can be utilised 2-3 times a year.                                                              int64
# consulted_involved                                                                                                                                  object
# e_mod_pref                                                                                                                                          object
# e_food_why                                                                                                                                          object
# e_food_why/Food is better for nutrition                                                                                                              int64
# e_food_why/Food meets food shortage                                                                                                                  int64
# e_food_why/Food prices are high in local market                                                                                                      int64
# e_food_why/Food is not available in the market                                                                                                       int64
# e_food_why/Better for children nutrition                                                                                                             int64
# e_food_why/Easy to share in case of need                                                                                                             int64
# e_food_why/Food is better controlled by women for household's food needs                                                                             int64
# e_food_why/Market places for food commodities are too far                                                                                            int64
# e_food_why/Quality of humanitarian food is better                                                                                                    int64
# e_food_why/Cash could be controlled/abused by men (drinking etc.)                                                                                    int64
# e_food_why/Women have more control on food compared to cash                                                                                          int64
# e_food_why/Other                                                                                                                                     int64
# e_cash_why/Flexibility of cash                                                                                                                       int64
# e_cash_why/Ability to buy preferred types of food                                                                                                    int64
# e_cash_why/Food prices are low in the local market                                                                                                   int64
# e_cash_why/No transport costs as compared to food                                                                                                    int64
# e_cash_why/It is not visible for others who seek sharing                                                                                             int64
# e_cash_why/It is better for dignity                                                                                                                  int64
# e_cash_why/Avoid sell of food at disadvantage prices                                                                                                 int64
# e_cash_why/Encourags savings for future opportunities                                                                                                int64
# e_cash_why/Other                                                                                                                                     int64
# e_voucher_why/Flexibility of Voucher                                                                                                                 int64
# e_voucher_why/It can be used to get preferred types of food                                                                                          int64
# e_voucher_why/Food prices are low in the local market                                                                                                int64
# e_voucher_why/No transport costs as compared to food                                                                                                 int64
# e_voucher_why/It is not visible for others who seek sharing                                                                                          int64
# e_voucher_why/It is better for dignity                                                                                                               int64
# e_voucher_why/Avoid sell of food at disadvantage prices                                                                                              int64
# e_voucher_why/Encourags savings for future opportunities                                                                                             int64
# e_voucher_why/Other                                                                                                                                  int64
# c_both_why/Both offer seasonal advantages                                                                                                            int64
# c_both_why/Minimize risks (losing all cash, poor quality food etc.)                                                                                  int64
# c_both_why/Safer approach than only cash or only food                                                                                                int64
# c_both_why/Controlled by both men and women,                                                                                                         int64
# c_both_why/It gives multiple options to diversify diets                                                                                              int64
# c_both_why/Coping capacity improved and reduced reliance only on food                                                                                int64
# c_both_why/Other                                                                                                                                     int64
# c_both_vouc_why/Both offer seasonal advantages                                                                                                       int64
# c_both_vouc_why/Minimize risks (losing all cash, poor quality food etc.)                                                                             int64
# c_both_vouc_why/Safer approach than only cash or only food                                                                                           int64
# c_both_vouc_why/Controlled by both men and women,                                                                                                    int64
# c_both_vouc_why/It gives multiple options to diversify diets                                                                                         int64
# c_both_vouc_why/Coping capacity improved and reduced reliance only on food                                                                           int64
# c_both_vouc_why/Other                                                                                                                                int64
# c_food_to_cash/Cereal                                                                                                                                int64
# c_food_to_cash/Pulses                                                                                                                                int64
# c_food_to_cash/Cooking Oil                                                                                                                           int64
# c_food_to_cash/Salt                                                                                                                                  int64
# c_food_to_voucher/Cereal                                                                                                                             int64
# c_food_to_voucher/Pulses                                                                                                                             int64
# c_food_to_voucher/Cooking Oil                                                                                                                        int64
# c_food_to_voucher/Salt                                                                                                                               int64
# f_entitled_all                                                                                                                                      object
# f_daylight                                                                                                                                          object
# f_comm                                                                                                                                              object
# f_dist_info                                                                                                                                         object
# f_dist_info/WFP directly                                                                                                                             int64
# f_dist_info/Cooperating Partners ( WVI, ACTED etc.)                                                                                                  int64
# f_dist_info/Project Management Committee (PMC)                                                                                                       int64
# f_dist_info/RRC                                                                                                                                      int64
# f_dist_info/Other                                                                                                                                    int64
# f_sameday                                                                                                                                           object
# f_sameday_why/Due to heavy rains/flooding                                                                                                            int64
# f_sameday_why/Due to difficult terrains                                                                                                              int64
# f_sameday_why/Due to insecurity in the area                                                                                                          int64
# f_sameday_why/Due to COVID-19 restrictions                                                                                                           int64
# f_sameday_why/Due to long distances                                                                                                                  int64
# f_sameday_why/Due to illness/mobility challenges                                                                                                     int64
# f_sameday_why/Due to late communication of distribution day                                                                                          int64
# f_sameday_why/Due to other household routines                                                                                                        int64
# f_sameday_why/Other reasons                                                                                                                          int64
# f_waitminutes                                                                                                                                       object
# f_return_time                                                                                                                                       object
# f_site_access                                                                                                                                       object
# f_who_access/Children                                                                                                                                int64
# f_who_access/Disabled                                                                                                                                int64
# f_who_access/Elderly                                                                                                                                 int64
# f_who_access/Ill                                                                                                                                     int64
# f_who_access/Men                                                                                                                                     int64
# f_who_access/Women                                                                                                                                   int64
# f_who_access/Other                                                                                                                                   int64
# f_access_diff/No shelter along the way                                                                                                               int64
# f_access_diff/Site itself is not appropriate                                                                                                         int64
# f_access_diff/Terrain is difficult                                                                                                                   int64
# f_access_diff/Too far                                                                                                                                int64
# f_access_diff/Unsafe                                                                                                                                 int64
# f_access_diff/Other                                                                                                                                  int64
# assist_end                                                                                                                                          object
# comType                                                                                                                                             object
# comType/Cereals                                                                                                                                      int64
# comType/Pulses                                                                                                                                       int64
# comType/Vegetable Oil                                                                                                                                int64
# comType/Salt                                                                                                                                         int64
# comType/CSB++                                                                                                                                        int64
# comType/Plumpy Sup/Acha Mum                                                                                                                          int64
# comType/LNS-MQ                                                                                                                                       int64
# assistance_effect                                                                                                                                   object
# FOOD_count                                                                                                                                         float64
# cashv_mainfood/Cereals grain or flour (maize, sorghum,…)                                                                                             int64
# cashv_mainfood/Rice                                                                                                                                  int64
# cashv_mainfood/Pulses (lentils, beans, peas, groundnuts, etc.)                                                                                       int64
# cashv_mainfood/Vegetables (onions, tomatoes, okra...) or leafy vegetables                                                                            int64
# cashv_mainfood/Fruits                                                                                                                                int64
# cashv_mainfood/Dairy (liquid or dry milk, youghurt, cheese)                                                                                          int64
# cashv_mainfood/Vegetable oil                                                                                                                         int64
# cashv_mainfood/Meat, fish, poultry, eggs                                                                                                             int64
# cashv_mainfood/Sugar, honey                                                                                                                          int64
# cashv_mainfood/Condiments (tea, coffee, salt, herbs, etc.)                                                                                           int64
# cashv_redeemissues/Long wait                                                                                                                         int64
# cashv_redeemissues/Non-voucher customers prioritized                                                                                                 int64
# cashv_redeemissues/Overcharging                                                                                                                      int64
# cashv_redeemissues/Pay for transport                                                                                                                 int64
# cashv_redeemissues/Poor service                                                                                                                      int64
# cashv_redeemissues/Receipt not provided                                                                                                              int64
# cashv_redeemissues/Preferred commodities unavailable                                                                                                 int64
# cashv_redeemissues/Poor food quality                                                                                                                 int64
# cashv_redeemissues/Trader not giving selected commodities                                                                                            int64
# cashv_redeemissues/Other                                                                                                                             int64
# millv_redeemissues/Long wait                                                                                                                         int64
# millv_redeemissues/Non-voucher customers prioritized                                                                                                 int64
# millv_redeemissues/Overcharging                                                                                                                      int64
# ...
# notdone_why/Fear of insecurity                                                                                                                       int64
# notdone_why/Fear of harassment                                                                                                                       int64
# notdone_why/Fear of theft or ambush                                                                                                                  int64
# notdone_why/Fear of abduction                                                                                                                        int64
# notdone_why/Flooding                                                                                                                                 int64
# notdone_why/Drought                                                                                                                                  int64
# notdone_why/I do not need to do these activities                                                                                                     int64
# notdone_why/Food insecurity                                                                                                                          int64
# notdone_why/I do not have cattle                                                                                                                     int64
# notdone_why/I do not have lands for crop cultivation                                                                                                 int64
# notdone_why/No area for fishing in our neighbourhood                                                                                                 int64
# notdone_why/Others (Specify)                                                                                                                         int64
# graze_insecurity/Fear of insecurity                                                                                                                  int64
# graze_insecurity/Fear of harassment                                                                                                                  int64
# graze_insecurity/Fear of theft or ambush                                                                                                             int64
# graze_insecurity/Fear of abduction                                                                                                                   int64
# graze_insecurity/Flooding                                                                                                                            int64
# graze_insecurity/Drought                                                                                                                             int64
# graze_insecurity/I do not need to go to that area                                                                                                    int64
# graze_insecurity/Others (Specify)                                                                                                                    int64
# grazing_section/No, we did not avoid                                                                                                                 int64
# grazing_section/Yes, because of Long-term dispute                                                                                                    int64
# grazing_section/Yes, because of Recent increase in fear of insecurity                                                                                int64
# grazing_section/Yes, because of distance                                                                                                             int64
# grazing_section/Others                                                                                                                               int64
# weapon_tools/Stick                                                                                                                                   int64
# weapon_tools/Spear                                                                                                                                   int64
# weapon_tools/Gun                                                                                                                                     int64
# weapon_tools/Knife                                                                                                                                   int64
# weapon_tools/Stones                                                                                                                                  int64
# weapon_tools/no tools                                                                                                                                int64
# hh_doneactivities/As adult, slept outside at night?                                                                                                  int64
# hh_doneactivities/As children, slept outside at night?                                                                                               int64
# hh_doneactivities/Getting home after dark after moving in your own village                                                                           int64
# hh_doneactivities/Eat dinner outside at night?                                                                                                       int64
# hh_doneactivities/Slept naked outside at night?                                                                                                      int64
# hh_doneactivities/Heard the night drum outside at night?                                                                                             int64
# hh_doneactivities/Stayed away overnight without accommodation organised in advance (women/men/ both)                                                 int64
# goods_traded/Sorghum, grains                                                                                                                         int64
# goods_traded/Vegetables                                                                                                                              int64
# goods_traded/Cattle                                                                                                                                  int64
# goods_traded/Livestock products                                                                                                                      int64
# goods_traded/Charcoal                                                                                                                                int64
# goods_traded/Wild products (fruits, Lalob/thau, wild meat)                                                                                           int64
# goods_traded/Fish                                                                                                                                    int64
# goods_traded/Medicine                                                                                                                                int64
# goods_traded/Household products (pots, pans, sheets, mosquito nets)                                                                                  int64
# goods_traded/Salt                                                                                                                                    int64
# goods_traded/Cooking Oil                                                                                                                             int64
# goods_traded/Other (specify)                                                                                                                         int64
# not_acccesscourt/Fear of revenge attack when people gathered                                                                                         int64
# not_acccesscourt/People busy with protecting the community                                                                                           int64
# not_acccesscourt/Local disputes not prioritised                                                                                                      int64
# not_acccesscourt/Other(Specify)                                                                                                                      int64
# ben_corvidinfo                                                                                                                                      object
# ben_corvidinfo_from                                                                                                                                 object
# ben_corvidinfo_from/Phone call and SMS                                                                                                               int64
# ben_corvidinfo_from/Radio and TV                                                                                                                     int64
# ben_corvidinfo_from/Newspaper                                                                                                                        int64
# ben_corvidinfo_from/From community                                                                                                                   int64
# ben_corvidinfo_from/Project management committee (PMC) Member                                                                                        int64
# ben_corvidinfo_from/Local authorities                                                                                                                int64
# ben_corvidinfo_from/Community Leader                                                                                                                 int64
# ben_corvidinfo_from/NGO/UN                                                                                                                           int64
# ben_corvid_access                                                                                                                                   object
# ben_corvid_access_yes/Afraid to contract virus                                                                                                       int64
# ben_corvid_access_yes/Community leader/local authorities prohibit to go to the site/ crowded area                                                    int64
# ben_corvid_access_yes/I have heard that there is a case in the community                                                                             int64
# ben_corvid_access_yes/I am afraid to go to the UN sites due to the high possibility of case                                                          int64
# ben_corvid_access_yes/Other                                                                                                                          int64
# u_phone                                                                                                                                             object
# u_consent/WFP Sharing your phone number with its implementing partners                                                                               int64
# u_consent/WFP Sharing your phone number with other humanitarian actors                                                                               int64
# u_consent/WFP Sharing your phone number with its contracted  companies                                                                               int64
# u_consent/No consent for all the above                                                                                                               int64
# starch1                                                                                                                                              int64
# pulses1                                                                                                                                              int64
# meat1                                                                                                                                                int64
# veg1                                                                                                                                                 int64
# fruit1                                                                                                                                               int64
# oil1                                                                                                                                                 int64
# milk1                                                                                                                                                int64
# fcs                                                                                                                                                float64
# fcsg                                                                                                                                                object
# fcsVitag                                                                                                                                            object
# fcsProtein                                                                                                                                          object
# fcshemeiron                                                                                                                                         object
# dds                                                                                                                                                  int64
# ddsg                                                                                                                                                object
# lcsi                                                                                                                                                object
# cari                                                                                                                                                object
# rcsi                                                                                                                                               float64
# rcsig                                                                                                                                               object
# total_fexcari                                                                                                                                      float64
# fexcari                                                                                                                                            float64
# expgroup                                                                                                                                             int64
# stress                                                                                                                                               int64
# crisis                                                                                                                                               int64
# emergency                                                                                                                                            int64
# caricop                                                                                                                                            float64
# fcsgtoCarig                                                                                                                                          int64
# fs                                                                                                                                                 float64
# _index                                                                                                                                               int64
# dtype: object

# %%
#REMOVE UNNECESARRY
#Keep only the relevant variables and Features based on literature review OF JOURNALS OF FOOD SECURITY 
# Family size, sex of HH head, level of education, age of the household head, number and types of communication media, income, numbers of livestock, cultivated land size, access to credit, flooding, conflict, 
#Received assistance, Food security group, land planted previous year, main source of livelihood, experience food shock, county, source of cereals, CARI Category

# %%
df = df[['a_county','respdnt_sex','respdnt_age','assist_received', 'head_marital','hh_size','totalhh','c_hh_ill','o_acc_med', 'H01','c_house', 'farm_animal', 'meals_adults', 'sourceCER', 'mkt_distance', 's_shock', 'sers_1', 'cari' ]]
#Look at age of HH head, proportion eaten, cattle owned, gfarm area, comarea,

# %%
#Check duplicates
df.duplicated().sum()
#Drop duplicate
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
#Rename certain variable names  to clear names
df = df.rename(columns = {'a_county': 'Count Name','respdnt_sex': 'Respondent sex','respdnt_age': 'Respondent age','assist_received': 'Received WFP assistance', 'head_marital': 'Marital status',\
                          'hh_size': 'Household size','totalhh': 'Total HH Members','c_hh_ill': 'HH has chronically ill member','o_acc_med': 'Access to medicine & health','H01': 'Main economic activity',\
                          'c_house': 'Type of house', 'farm_animal': 'Has farm animals', 'meals_adults': 'Meals eaten by adults', 'sourceCER': 'Source Cereals', 'mkt_distance': 'Distance to markets',\
                          's_shock': 'Main shock', 'sers_1' : 'Can bounce back', 'cari': 'Food security status'})

# %%
#Check data types
df.dtypes
# Out:
# Count Name                        object
# Respondent sex                    object
# Respondent age                     int64
# Received WFP assistance           object
# Marital status                    object
# Household size                   float64
# Total HH Members                 float64
# HH has chronically ill member     object
# Access to medicine & health       object
# Main economic activity            object
# Type of house                     object
# Has farm animals                  object
# Meals eaten by adults            float64
# Source Cereals                    object
# Distance to markets              float64
# Main shock                        object
# Can bounce back                   object
# Food security status              object
# dtype: object

# %%
#Check and replace missing values
df.isnull().sum()
# Out:
# Count Name                         0
# Respondent sex                     0
# Respondent age                     0
# Received WFP assistance            4
# Marital status                    17
# Household size                    17
# Total HH Members                  17
# HH has chronically ill member     17
# Access to medicine & health       21
# Main economic activity            17
# Type of house                     21
# Has farm animals                  17
# Meals eaten by adults             17
# Source Cereals                    37
# Distance to markets              240
# Main shock                        17
# Can bounce back                   17
# Food security status               0
# dtype: int64

# %%
#Few missing values. Replace the continpus variables and the categorical variables using 
from sklearn.compose import make_column_selector
from sklearn.impute import SimpleImputer

# %%
#instantiate the selectors to for numeric and categorical data types
num_selector = make_column_selector(dtype_include='number')
cat_selector = make_column_selector(dtype_include='object')

# %%
#Obtain Categorical values from test data
cat_selector = make_column_selector(dtype_include='object')
df_cat  = df[cat_selector(df)]
df_cat.head()
# Out:
#   Count Name Respondent sex Received WFP assistance      Marital status  \
# 0    Rubkona         Female                     Yes     Married/Partner
# 1    Rubkona         Female                     Yes             Widowed
# 2    Rubkona         Female                     Yes             Widowed
# 3    Rubkona         Female                     Yes  Divorced/Separated
# 4    Awerial           Male                     Yes     Married/Partner
#
#   HH has chronically ill member Access to medicine & health  \
# 0                            No                         Yes
# 1                            No                         Yes
# 2                            No                         Yes
# 3                            No                         Yes
# 4                            No                          No
#
#                     Main economic activity               Type of house  \
# 0  Food assistance/Sale of food assistance                   Straw hut
# 1  Food assistance/Sale of food assistance  Rakooba/Improvised Shelter
# 2  Food assistance/Sale of food assistance  Rakooba/Improvised Shelter
# 3  Food assistance/Sale of food assistance                   Straw hut
# 4  Food assistance/Sale of food assistance  Rakooba/Improvised Shelter
#
#   Has farm animals                    Source Cereals  \
# 0               No  Market (Purchase cash or credit)
# 1               No  Support from neighbors/relatives
# 2               No  Market (Purchase cash or credit)
# 3               No  Market (Purchase cash or credit)
# 4              Yes                   Food assistance
#
#                                           Main shock Can bounce back  \
# 0  High food prices Delayed assistance distributions           Agree
# 1  Floods, heavy rains, landslides High food pric...           Agree
# 2  Floods, heavy rains, landslides High food pric...           Agree
# 3                               Human sickness/death           Agree
# 4  High food prices Food shortages/reduced distri...         Neutral
#
#        Food security status
# 0    Marginally food secure
# 1    Severely food insecure
# 2  Moderately food insecure
# 3  Moderately food insecure
# 4  Moderately food insecure

# %%
#Extract Numeric Values 
cat_selector = make_column_selector(dtype_include='number')
df_num  = df[cat_selector(df)]
df_num .head()
# Out:
#    Respondent age  Household size  Total HH Members  Meals eaten by adults  \
# 0              32             6.0               6.0                    2.0
# 1              48             9.0               9.0                    2.0
# 2              41            10.0              10.0                    2.0
# 3              33            11.0              11.0                    2.0
# 4              68             5.0               5.0                    2.0
#
#    Distance to markets
# 0                 35.0
# 1                 60.0
# 2                 30.0
# 3                 15.0
# 4                 30.0

# %%
#REPLACE ANY MISSING VALUES 
#instantiate SimpleImputers with most_frequent and mean strategies
freq_imputer = SimpleImputer(strategy='most_frequent')
mean_imputer = SimpleImputer(strategy='mean')

# %%
 #Impute for missing numeric variables 
df_num = pd.DataFrame(mean_imputer.fit_transform(df_num), columns = df_num.columns)
df_num.isnull().sum()
# Out:
# Respondent age           0
# Household size           0
# Total HH Members         0
# Meals eaten by adults    0
# Distance to markets      0
# dtype: int64

# %%
 #Impute for missing Categorical variables 
df_cat = pd.DataFrame(freq_imputer.fit_transform(df_cat), columns = df_cat.columns)
df_cat.isnull().sum()
# Out:
# Count Name                       0
# Respondent sex                   0
# Received WFP assistance          0
# Marital status                   0
# HH has chronically ill member    0
# Access to medicine & health      0
# Main economic activity           0
# Type of house                    0
# Has farm animals                 0
# Source Cereals                   0
# Main shock                       0
# Can bounce back                  0
# Food security status             0
# dtype: int64

# %%
#Concatenate Numerical and Categorical data
# Combine the categorical and numerical dataframes
df = pd.concat([df_num, df_cat], axis=1)
df.head()
# Out:
#    Respondent age  Household size  Total HH Members  Meals eaten by adults  \
# 0            32.0             6.0               6.0                    2.0
# 1            48.0             9.0               9.0                    2.0
# 2            41.0            10.0              10.0                    2.0
# 3            33.0            11.0              11.0                    2.0
# 4            68.0             5.0               5.0                    2.0
#
#    Distance to markets Count Name Respondent sex Received WFP assistance  \
# 0                 35.0    Rubkona         Female                     Yes
# 1                 60.0    Rubkona         Female                     Yes
# 2                 30.0    Rubkona         Female                     Yes
# 3                 15.0    Rubkona         Female                     Yes
# 4                 30.0    Awerial           Male                     Yes
#
#        Marital status HH has chronically ill member  \
# 0     Married/Partner                            No
# 1             Widowed                            No
# 2             Widowed                            No
# 3  Divorced/Separated                            No
# 4     Married/Partner                            No
#
#   Access to medicine & health                   Main economic activity  \
# 0                         Yes  Food assistance/Sale of food assistance
# 1                         Yes  Food assistance/Sale of food assistance
# 2                         Yes  Food assistance/Sale of food assistance
# 3                         Yes  Food assistance/Sale of food assistance
# 4                          No  Food assistance/Sale of food assistance
#
#                 Type of house Has farm animals  \
# 0                   Straw hut               No
# 1  Rakooba/Improvised Shelter               No
# 2  Rakooba/Improvised Shelter               No
# 3                   Straw hut               No
# 4  Rakooba/Improvised Shelter              Yes
#
#                      Source Cereals  \
# 0  Market (Purchase cash or credit)
# 1  Support from neighbors/relatives
# 2  Market (Purchase cash or credit)
# 3  Market (Purchase cash or credit)
# 4                   Food assistance
#
#                                           Main shock Can bounce back  \
# 0  High food prices Delayed assistance distributions           Agree
# 1  Floods, heavy rains, landslides High food pric...           Agree
# 2  Floods, heavy rains, landslides High food pric...           Agree
# 3                               Human sickness/death           Agree
# 4  High food prices Food shortages/reduced distri...         Neutral
#
#        Food security status
# 0    Marginally food secure
# 1    Severely food insecure
# 2  Moderately food insecure
# 3  Moderately food insecure
# 4  Moderately food insecure

# %%
df.dtypes
# Out:
# Respondent age                   float64
# Household size                   float64
# Total HH Members                 float64
# Meals eaten by adults            float64
# Distance to markets              float64
# Count Name                        object
# Respondent sex                    object
# Received WFP assistance           object
# Marital status                    object
# HH has chronically ill member     object
# Access to medicine & health       object
# Main economic activity            object
# Type of house                     object
# Has farm animals                  object
# Source Cereals                    object
# Main shock                        object
# Can bounce back                   object
# Food security status              object
# dtype: object

# %% [markdown]
# ***PART 3 BEGINS FROM HERE***

# %%
#Bar graph for the  the taraget variable 
# importing the required library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Food security by HH size
plt.figure(figsize=(10,7))
sns.barplot(x = df['Food security status'], y =df['Household size'], palette = 'rocket')
# Show the plot
plt.show()
#Relationshio between food security and housheold size is not well developed

# %%
#Overall distribution of the food secuirty classes

plt.figure(figsize=(8,6))
sns.countplot (x = 'Food security status', palette = 'rocket', data = df)
 # Show the plot
plt.show()
#Most people are moderately food insecure

# %%
sns.heatmap(df.corr(), cbar = True, linewidths= 0.6)
# Out:
# <ipython-input-32-9b6c0c765174>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cbar = True, linewidths= 0.6)
# <Axes: >

# %%
#Food security by distance to markets
plt.figure(figsize=(12,8))
plt.title('Distance to markets nd Food Security Status')
sns.barplot(x = df['Food security status'], y =df['Distance to markets'], palette = 'rocket')
# Show the plot
plt.show()

# %%
df_stats = df.describe().transpose()
df_stats
# Out:
#                         count       mean         std   min   25%   50%  \
# Respondent age         3185.0  36.787441   12.311686  15.0  28.0  35.0
# Household size         3185.0   6.516414    2.729144   1.0   5.0   6.0
# Total HH Members       3185.0   6.516414    2.729144   1.0   5.0   6.0
# Meals eaten by adults  3185.0   2.451705    8.625016   0.0   1.0   2.0
# Distance to markets    3185.0  53.271986  381.304096   0.0  10.0  30.0
#
#                              75%      max
# Respondent age         45.000000     95.0
# Household size          8.000000     28.0
# Total HH Members        8.000000     28.0
# Meals eaten by adults   2.000000     99.0
# Distance to markets    53.271986  20000.0
